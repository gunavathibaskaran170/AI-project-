# %% [markdown]
# <a href="https://colab.research.google.com/github/gunavathibaskaran170/AI-project-/blob/main/LangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain groq faiss-cpu sentence-transformers tiktoken
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 29.5 MB/s eta 0:00:00
# ...

# %%
# !pip install -U langchain langchain-community #for error occuring while downloading
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 51.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.3/554.3 kB 38.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.0
#     Uninstalling langchain-core-1.4.0:
#       Successfully uninstalled langchain-core-1.4.0
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.4
#     Uninstalling langchain-1.3.4:
#       Successfully uninstalled langchain-1.3.4
# ...

# %%
# !pip install langchain langchain-community langchain-huggingface langchain-groq faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: groq
#     Found existing installation: groq 1.4.0
#     Uninstalling groq-1.4.0:
#       Successfully uninstalled groq-1.4.0
# ...

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_classic.chains import RetrievalQA
from langchain_groq import ChatGroq
# Out:
# /tmp/ipykernel_9033/3438867477.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader("/content/drive/MyDrive/sample.txt")
documents =loader.load()

# %%
splitter = CharacterTextSplitter(chunk_size=1000,chunk_overlap=50)
docs=splitter.split_documents(documents)

# %%
embeddings=HuggingFaceEmbeddings()
vectorstore =FAISS.from_documents(docs, embeddings)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# ...

# %%
from google.colab import userdata
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0,
    groq_api_key=userdata.get('langchain')  # <-- Add this line
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever()
)

query = "What is the summary of the document?"
response = qa_chain.invoke({"query": query})

print(response["result"])
# Out:
# The document discusses Zoho's approach to Artificial Intelligence (AI) and Machine Learning (ML). It mentions that Zoho has been involved with AI for over a decade and has a research team called ZLabs, which works with product teams to incorporate AI into existing and upcoming applications. The team follows a hub and spoke model, with ZLabs as the central hub, and allocates its time as follows: 50% on research, 40% on development, and 10% on collaboration. The goal is to give more autonomy to AI and use it for decision-making, shifting from product automation to decision automation.
