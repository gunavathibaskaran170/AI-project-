# %% [markdown]
# <a href="https://colab.research.google.com/github/gunavathibaskaran170/AI-project-/blob/main/Association_Rule_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/DATASET /Market_Basket_Optimisation.csv",header=None)

# %% [markdown]
# # **Header=None means It add the Header to dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7501 non-null   object
#  1   1       5747 non-null   object
#  2   2       4389 non-null   object
#  3   3       3345 non-null   object
#  4   4       2529 non-null   object
#  5   5       1864 non-null   object
#  6   6       1369 non-null   object
#  7   7       981 non-null    object
#  8   8       654 non-null    object
#  9   9       395 non-null    object
#  10  10      256 non-null    object
#  11  11      154 non-null    object
#  12  12      87 non-null     object
#  13  13      47 non-null     object
#  14  14      25 non-null     object
#  15  15      8 non-null      object
#  16  16      4 non-null      object
#  17  17      4 non-null      object
#  18  18      3 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#                    0              1              2              3          4   \
# count            7501           5747           4389           3345       2529
# unique            115            117            115            114        110
# top     mineral water  mineral water  mineral water  mineral water  green tea
# freq              577            484            375            201        153
#
#                   5          6          7          8          9   \
# count           1864       1369        981        654        395
# unique           106        102         98         88         80
# top     french fries  green tea  green tea  green tea  green tea
# freq             107         96         67         57         31
#
#                     10         11         12         13         14      15  \
# count              256        154         87         47         25       8
# unique              66         50         43         28         19       8
# ...

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
len(df)
# Out:
# 7501

# %%
transactions=[]
for i in range(0,len(df)):
  transactions.append([str(df.values[i,j])for j in range(0,20) if str(df.values[i,j])!='nan'])

# %%
transactions

# %%
# !pip install apyori

# %%
from apyori import apriori
rules=apriori(transactions=transactions,min_support=0.003,min_confidence=0.2, min_lift=3,min__length=2,max_length=2)
results=list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %%
import pandas as pd

data = []

for rule in results:

    support = rule.support

    for stat in rule.ordered_statistics:

        lhs = ', '.join(list(stat.items_base))
        rhs = ', '.join(list(stat.items_add))
        confidence = stat.confidence
        lift = stat.lift

        data.append([lhs, rhs, support, confidence, lift])

df_rules = pd.DataFrame(
    data,
    columns=['LHS', 'RHS', 'Support', 'Confidence', 'Lift']
)

print(df_rules)
# Out:
#                     LHS          RHS   Support  Confidence      Lift
# 0           light cream      chicken  0.004533    0.290598  4.843951
# 1  mushroom cream sauce     escalope  0.005733    0.300699  3.790833
# 2                 pasta     escalope  0.005866    0.372881  4.700812
# 3         fromage blanc        honey  0.003333    0.245098  5.164271
# 4         herb & pepper  ground beef  0.015998    0.323450  3.291994
# 5          tomato sauce  ground beef  0.005333    0.377358  3.840659
# 6           light cream    olive oil  0.003200    0.205128  3.114710
# 7     whole wheat pasta    olive oil  0.007999    0.271493  4.122410
# 8                 pasta       shrimp  0.005066    0.322034  4.506672

# %%
import pandas as pd

df = pd.DataFrame(
    [[list(i[2][0][0]),
      list(i[2][0][1]),
      i[1],
      i[2][0][2],
      i[2][0][3]]
     for i in results],
    columns=['LHS', 'RHS', 'Support', 'Confidence', 'Lift']
)
print(df)
# Out:
#                       LHS            RHS   Support  Confidence      Lift
# 0           [light cream]      [chicken]  0.004533    0.290598  4.843951
# 1  [mushroom cream sauce]     [escalope]  0.005733    0.300699  3.790833
# 2                 [pasta]     [escalope]  0.005866    0.372881  4.700812
# 3         [fromage blanc]        [honey]  0.003333    0.245098  5.164271
# 4         [herb & pepper]  [ground beef]  0.015998    0.323450  3.291994
# 5          [tomato sauce]  [ground beef]  0.005333    0.377358  3.840659
# 6           [light cream]    [olive oil]  0.003200    0.205128  3.114710
# 7     [whole wheat pasta]    [olive oil]  0.007999    0.271493  4.122410
# 8                 [pasta]       [shrimp]  0.005066    0.322034  4.506672
